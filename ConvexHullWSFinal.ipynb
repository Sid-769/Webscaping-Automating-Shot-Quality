# %%
import json

json_data = '''
{
  "sectionOrder": [
    "top-stat-card",
    "shotmap",
    "stats-section"
  ],
  "topStatCard": {
    "id": "top-stat-card",
    "type": "stat-values",
    "display": "stats-group",
    "title": "Top stat card",
    "localizedTitleId": "top_stat_card",
    "items": [
      {
        "title": "Goals",
        "localizedTitleId": "goals",
        "statValue": "15",
        "per90": 0.721153846153846,
        "percentileRank": 87.1428571428571,
        "percentileRankPer90": 92.8571428571429,
        "statFormat": "number"
      },
      {
        "title": "Assists",
        "localizedTitleId": "assists",
        "statValue": "5",
        "per90": 0.240384615384615,
        "percentileRank": 85.7142857142857,
        "percentileRankPer90": 85.7142857142857,
        "statFormat": "number"
      },
      {
        "title": "Rating",
        "localizedTitleId": "rating",
        "statValue": "7.53",
        "per90": 7.53423076923077,
        "percentileRank": 97.1428571428571,
        "percentileRankPer90": 97.1428571428571,
        "statFormat": "fraction"
      },
      {
        "title": "Matches",
        "localizedTitleId": "matches_uppercase",
        "statValue": "26",
        "per90": 26,
        "percentileRank": 44.2857142857143,
        "percentileRankPer90": 44.2857142857143,
        "statFormat": "number"
      },
      {
        "title": "Started",
        "localizedTitleId": "started",
        "statValue": "22",
        "per90": 22,
        "percentileRank": 68.5714285714286,
        "percentileRankPer90": 72.8571428571429,
        "statFormat": "number"
      },
      {
        "title": "Minutes",
        "localizedTitleId": "minutes_played",
        "statValue": "1872",
        "per90": 90,
        "percentileRank": 68.5714285714286,
        "percentileRankPer90": 100,
        "statFormat": "number"
      }
    ]
  },
  "statsSection": {
    "id": "stats-section",
    "type": "grouped-stat-values",
    "title": "Season performance",
    "localizedTitleId": "season_performance",
    "subTitle": "Stats compared to other forwards",
    "localizedSubTitleId": "stats_comparison_forwards",
    "items": [
      {
        "type": "stat-values",
        "display": "stats-group",
        "title": "Shooting",
        "localizedTitleId": "shooting",
        "items": [
          {
            "title": "Goals",
            "localizedTitleId": "goals",
            "statValue": "15",
            "per90": 0.721153846153846,
            "percentileRank": 87.1428571428571,
            "percentileRankPer90": 92.8571428571429,
            "statFormat": "number"
          },
          {
            "title": "xG",
            "localizedTitleId": "expected_goals",
            "statValue": "13.11",
            "per90": 0.630298073475177,
            "percentileRank": 91.4285714285714,
            "percentileRankPer90": 87.1428571428571,
            "statFormat": "fraction"
          },
          {
            "title": "xGOT",
            "localizedTitleId": "expected_goals_on_target",
            "statValue": "15.74",
            "per90": 0.756524021808918,
            "percentileRank": 94.2857142857143,
            "percentileRankPer90": 94.2857142857143,
            "statFormat": "fraction"
          },
          {
            "title": "Penalty goals",
            "localizedTitleId": "goals_subtitle",
            "statValue": "1",
            "per90": 0.0480769230769231,
            "percentileRank": 70,
            "percentileRankPer90": 72.8571428571429,
            "statFormat": "number"
          },
          {
            "title": "xG excl. penalty",
            "localizedTitleId": "non_penalty_xg",
            "statValue": "12.32",
            "per90": 0.592394241919884,
            "percentileRank": 91.4285714285714,
            "percentileRankPer90": 91.4285714285714,
            "statFormat": "fraction"
          },
          {
            "title": "Shots",
            "localizedTitleId": "shots",
            "statValue": "78",
            "per90": 3.75,
            "percentileRank": 88.5714285714286,
            "percentileRankPer90": 90,
            "statFormat": "number"
          },
          {
            "title": "Shots on target",
            "localizedTitleId": "ShotsOnTarget",
            "statValue": "39",
            "per90": 1.875,
            "percentileRank": 95.7142857142857,
            "percentileRankPer90": 97.1428571428571,
            "statFormat": "number"
          }
        ]
      },
      {
        "type": "stat-values",
        "display": "stats-group",
        "title": "Passing",
        "localizedTitleId": "passing",
        "items": [
          {
            "title": "Assists",
            "localizedTitleId": "assists",
            "statValue": "5",
            "per90": 0.240384615384615,
            "percentileRank": 85.7142857142857,
            "percentileRankPer90": 85.7142857142857,
            "statFormat": "number"
          },
          {
            "title": "xA",
            "localizedTitleId": "expected_assists",
            "statValue": "4.38",
            "per90": 0.210470167490152,
            "percentileRank": 94.2857142857143,
            "percentileRankPer90": 92.8571428571429,
            "statFormat": "fraction"
          },
          {
            "title": "Accurate passes",
            "localizedTitleId": "successful_passes",
            "statValue": "486",
            "per90": 23.3653846153846,
            "percentileRank": 91.4285714285714,
            "percentileRankPer90": 88.5714285714286,
            "statFormat": "number"
          },
          {
            "title": "Pass accuracy",
            "localizedTitleId": "successful_passes_accuracy",
            "statValue": "78.1",
            "per90": 78.1350482315113,
            "percentileRank": 75.7142857142857,
            "percentileRankPer90": 75.7142857142857,
            "statFormat": "percent"
          },
          {
            "title": "Accurate long balls",
            "localizedTitleId": "long_balls_accurate",
            "statValue": "32",
            "per90": 1.53846153846154,
            "percentileRank": 94.2857142857143,
            "percentileRankPer90": 95.7142857142857,
            "statFormat": "number"
          },
          {
            "title": "Long ball accuracy",
            "localizedTitleId": "long_ball_succeeeded_accuracy",
            "statValue": "61.5",
            "per90": 61.5384615384615,
            "percentileRank": 58.5714285714286,
            "percentileRankPer90": 58.5714285714286,
            "statFormat": "percent"
          },
          {
            "title": "Chances created",
            "localizedTitleId": "chances_created",
            "statValue": "31",
            "per90": 1.49038461538462,
            "percentileRank": 87.1428571428571,
            "percentileRankPer90": 84.2857142857143,
            "statFormat": "number"
          },
          {
            "title": "Successful crosses",
            "localizedTitleId": "crosses_succeeeded",
            "statValue": "6",
            "per90": 0.288461538461538,
            "percentileRank": 85.7142857142857,
            "percentileRankPer90": 77.1428571428572,
            "statFormat": "number"
          },
          {
            "title": "Cross accuracy",
            "localizedTitleId": "crosses_succeeeded_accuracy",
            "statValue": "10.7",
            "per90": 10.7142857142857,
            "percentileRank": 41.4285714285714,
            "percentileRankPer90": 41.4285714285714,
            "statFormat": "percent"
          }
        ]
      },
      {
        "type": "stat-values",
        "display": "stats-group",
        "title": "Possession",
        "localizedTitleId": "possession",
        "items": [
          {
            "title": "Dribbles",
            "localizedTitleId": "dribbles_succeeded",
            "statValue": "65",
            "per90": 3.125,
            "percentileRank": 100,
            "percentileRankPer90": 100,
            "statFormat": "number"
          },
          {
            "title": "Dribbles success rate",
            "localizedTitleId": "won_contest_subtitle",
            "statValue": "40.6",
            "per90": 40.625,
            "percentileRank": 35.7142857142857,
            "percentileRankPer90": 35.7142857142857,
            "statFormat": "percent"
          },
          {
            "title": "Touches",
            "localizedTitleId": "touches",
            "statValue": "1206",
            "per90": 57.9807692307692,
            "percentileRank": 91.4285714285714,
            "percentileRankPer90": 95.7142857142857,
            "statFormat": "number"
          },
          {
            "title": "Touches in opposition box",
            "localizedTitleId": "touches_opp_box",
            "statValue": "221",
            "per90": 10.625,
            "percentileRank": 97.1428571428571,
            "percentileRankPer90": 100,
            "statFormat": "number"
          },
          {
            "title": "Dispossessed",
            "localizedTitleId": "dispossessed",
            "statValue": "40",
            "per90": 1.92307692307692,
            "percentileRank": 7.14285714285714,
            "percentileRankPer90": 21.4285714285714,
            "statFormat": "number"
          },
          {
            "title": "Fouls won",
            "localizedTitleId": "fouls_won",
            "statValue": "54",
            "per90": 2.59615384615385,
            "percentileRank": 94.2857142857143,
            "percentileRankPer90": 91.4285714285714,
            "statFormat": "number"
          }
        ]
      },
      {
        "type": "stat-values",
        "display": "stats-group",
        "title": "Defending",
        "localizedTitleId": "defending",
        "items": [
          {
            "title": "Tackles won",
            "localizedTitleId": "tackles_succeeded",
            "statValue": "13",
            "per90": 0.625,
            "percentileRank": 82.8571428571429,
            "percentileRankPer90": 67.1428571428571,
            "statFormat": "number"
          },
          {
            "title": "Tackles won %",
            "localizedTitleId": "tackles_succeeded_percent",
            "statValue": "72.2",
            "per90": 72.2222222222222,
            "percentileRank": 82.8571428571429,
            "percentileRankPer90": 82.8571428571429,
            "statFormat": "percent"
          },
          {
            "title": "Duels won",
            "localizedTitleId": "duel_won",
            "statValue": "138",
            "per90": 6.63461538461539,
            "percentileRank": 85.7142857142857,
            "percentileRankPer90": 68.5714285714286,
            "statFormat": "number"
          },
          {
            "title": "Duels won %",
            "localizedTitleId": "duel_won_percent",
            "statValue": "44.2",
            "per90": 44.2307692307692,
            "percentileRank": 65.7142857142857,
            "percentileRankPer90": 65.7142857142857,
            "statFormat": "percent"
          },
          {
            "title": "Aerials won",
            "localizedTitleId": "aerials_won",
            "statValue": "1",
            "per90": 0.0480769230769231,
            "percentileRank": 0,
            "percentileRankPer90": 0,
            "statFormat": "number"
          },
          {
            "title": "Aerials won %",
            "localizedTitleId": "aerials_won_percent",
            "statValue": "12.5",
            "per90": 12.5,
            "percentileRank": 0,
            "percentileRankPer90": 0,
            "statFormat": "percent"
          },
          {
            "title": "Interceptions",
            "localizedTitleId": "interceptions",
            "statValue": "1",
            "per90": 0.0480769230769231,
            "percentileRank": 25.7142857142857,
            "percentileRankPer90": 28.5714285714286,
            "statFormat": "number"
          },
          {
            "title": "Blocked scoring attempt",
            "localizedTitleId": "shot_blocked",
            "statValue": "16",
            "per90": 0.769230769230769,
            "percentileRank": 87.1428571428571,
            "percentileRankPer90": 81.4285714285714,
            "statFormat": "number"
          },
          {
            "title": "Fouls committed",
            "localizedTitleId": "fouls",
            "statValue": "24",
            "per90": 1.15384615384615,
            "percentileRank": 64.2857142857143,
            "percentileRankPer90": 28.5714285714286,
            "statFormat": "number"
          },
          {
            "title": "Recoveries",
            "localizedTitleId": "recoveries",
            "statValue": "44",
            "per90": 2.11538461538462,
            "percentileRank": 64.2857142857143,
            "percentileRankPer90": 24.2857142857143,
            "statFormat": "number"
          },
          {
            "title": "Possession won final 3rd",
            "localizedTitleId": "poss_won_att_3rd_team_title",
            "statValue": "16",
            "per90": 0.769230769230769,
            "percentileRank": 82.8571428571429,
            "percentileRankPer90": 75.7142857142857,
            "statFormat": "number"
          },
          {
            "title": "Dribbled past",
            "localizedTitleId": "dribbled_past",
            "statValue": "9",
            "per90": 0.432692307692308,
            "percentileRank": 28.5714285714286,
            "percentileRankPer90": 54.2857142857143,
            "statFormat": "number"
          }
        ]
      },
      {
        "type": "stat-values",
        "display": "stats-group",
        "title": "Discipline",
        "localizedTitleId": "discipline",
        "items": [
          {
            "title": "Yellow cards",
            "localizedTitleId": "yellow_cards",
            "statValue": "7",
            "per90": 0.336538461538462,
            "percentileRank": 2.85714285714286,
            "percentileRankPer90": 18.5714285714286,
            "statFormat": "number"
          },
          {
            "title": "Red cards",
            "localizedTitleId": "red_cards",
            "statValue": "0",
            "per90": 0,
            "percentileRank": 100,
            "percentileRankPer90": 100,
            "statFormat": "number"
          }
        ]
      }
    ]
  },
  "shotmap": [
    {
      "id": 2576189201,
      "eventType": "AttemptSaved",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 95.1578947355,
      "y": 44.0708280208,
      "min": 35,
      "isBlocked": false,
      "isOnTarget": true,
      "blockedX": 101.9655172416,
      "blockedY": 37.27875,
      "goalCrossedY": 36.36375,
      "goalCrossedZ": 0.8154736802,
      "expectedGoals": 0.0983025804162026,
      "expectedGoalsOnTarget": 0.2949,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "FirstHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0.374669312169311,
        "y": 0.215733777830688,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8315,
      "awayTeamId": 8633,
      "homeTeamName": "Athletic Club",
      "awayTeamName": "Real Madrid",
      "homeScore": 0,
      "awayScore": 2,
      "matchId": 4205344,
      "matchDate": "2023-08-12T19:30:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2576189253,
      "eventType": "AttemptSaved",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 97.0877192975,
      "y": 44.351082798,
      "min": 35,
      "isBlocked": true,
      "isOnTarget": true,
      "blockedX": 98.1491228066,
      "blockedY": 43.044375,
      "goalCrossedY": 34.22875,
      "goalCrossedZ": 1.219999994,
      "expectedGoals": 0.0666024833917618,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "FirstHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0.939484126984128,
        "y": 0.322751321164021,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8315,
      "awayTeamId": 8633,
      "homeTeamName": "Athletic Club",
      "awayTeamName": "Real Madrid",
      "homeScore": 0,
      "awayScore": 2,
      "matchId": 4205344,
      "matchDate": "2023-08-12T19:30:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2576234879,
      "eventType": "AttemptSaved",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 94.7719298231,
      "y": 42.8709375,
      "min": 70,
      "isBlocked": false,
      "isOnTarget": true,
      "blockedX": 102.8189655174,
      "blockedY": 36.21125,
      "goalCrossedY": 32.55125,
      "goalCrossedZ": 0.4045263138,
      "expectedGoals": 0.0901567861437798,
      "expectedGoalsOnTarget": 0.1677,
      "shotType": "RightFoot",
      "situation": "FastBreak",
      "period": "SecondHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 1.3832671957672,
        "y": 0.107017543333333,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8315,
      "awayTeamId": 8633,
      "homeTeamName": "Athletic Club",
      "awayTeamName": "Real Madrid",
      "homeScore": 0,
      "awayScore": 2,
      "matchId": 4205344,
      "matchDate": "2023-08-12T19:30:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2579162431,
      "eventType": "Miss",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 75.9529126232,
      "y": 37.43125,
      "min": 8,
      "isBlocked": false,
      "isOnTarget": false,
      "goalCrossedY": 25.0134375,
      "goalCrossedZ": 0.4430526294,
      "expectedGoals": 0.0174122992902994,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "FirstHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 2,
        "y": 0.049301680080676,
        "zoomRatio": 0.420628021003582
      },
      "isSavedOffLine": false,
      "isFromInsideBox": false,
      "box": "OutsideBox",
      "homeTeamId": 9865,
      "awayTeamId": 8633,
      "homeTeamName": "Almeria",
      "awayTeamName": "Real Madrid",
      "homeScore": 1,
      "awayScore": 3,
      "matchId": 4205353,
      "matchDate": "2023-08-19T17:30:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2579169633,
      "eventType": "AttemptSaved",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 101.8706896554,
      "y": 44.9816560467,
      "min": 15,
      "isBlocked": true,
      "isOnTarget": true,
      "blockedX": 102.2500000002,
      "blockedY": 44.0007643265,
      "goalCrossedY": 36.745,
      "goalCrossedZ": 1.219999994,
      "expectedGoals": 0.0413950942456722,
      "shotType": "LeftFoot",
      "situation": "RegularPlay",
      "period": "FirstHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0.273809523809523,
        "y": 0.322751321164021,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 9865,
      "awayTeamId": 8633,
      "homeTeamName": "Almeria",
      "awayTeamName": "Real Madrid",
      "homeScore": 1,
      "awayScore": 3,
      "matchId": 4205353,
      "matchDate": "2023-08-19T17:30:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2579249593,
      "eventType": "Goal",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 91.1,
      "y": 28.959285713,
      "min": 73,
      "isBlocked": false,
      "isOnTarget": true,
      "goalCrossedY": 36.2875,
      "goalCrossedZ": 1.8685263066,
      "expectedGoals": 0.117700003087521,
      "expectedGoalsOnTarget": 0.4182,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "SecondHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0.39484126984127,
        "y": 0.494319128730159,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 9865,
      "awayTeamId": 8633,
      "homeTeamName": "Almeria",
      "awayTeamName": "Real Madrid",
      "homeScore": 1,
      "awayScore": 3,
      "matchId": 4205353,
      "matchDate": "2023-08-19T17:30:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2579251491,
      "eventType": "Miss",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 92.2,
      "y": 46.3829299327,
      "min": 75,
      "isBlocked": false,
      "isOnTarget": false,
      "goalCrossedY": 35.22,
      "goalCrossedZ": 3.8547586248,
      "expectedGoals": 0.0534339621663094,
      "shotType": "RightFoot",
      "situation": "FastBreak",
      "period": "SecondHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0.78565625849368,
        "y": 0.677248677248677,
        "zoomRatio": 0.664114215486793
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 9865,
      "awayTeamId": 8633,
      "homeTeamName": "Almeria",
      "awayTeamName": "Real Madrid",
      "homeScore": 1,
      "awayScore": 3,
      "matchId": 4205353,
      "matchDate": "2023-08-19T17:30:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2596049587,
      "eventType": "AttemptSaved",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 92.5,
      "y": 40.385476191,
      "min": 61,
      "isBlocked": true,
      "isOnTarget": true,
      "blockedX": 94.0964912264,
      "blockedY": 39.713095239,
      "goalCrossedY": 36.05875,
      "goalCrossedZ": 1.219999994,
      "expectedGoals": 0.0617074966430664,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "SecondHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0.455357142857142,
        "y": 0.322751321164021,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8633,
      "awayTeamId": 8306,
      "homeTeamName": "Real Madrid",
      "awayTeamName": "Las Palmas",
      "homeScore": 2,
      "awayScore": 0,
      "matchId": 4205411,
      "matchDate": "2023-09-27T17:00:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2601219939,
      "eventType": "Miss",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 91.2,
      "y": 42.2928125,
      "min": 24,
      "isBlocked": false,
      "isOnTarget": false,
      "goalCrossedY": 33.5425,
      "goalCrossedZ": 5.3059310432,
      "expectedGoals": 0.0722117200493812,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "FirstHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 1.05839526886396,
        "y": 0.677248677248677,
        "zoomRatio": 0.48247894274481
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8633,
      "awayTeamId": 8371,
      "homeTeamName": "Real Madrid",
      "awayTeamName": "Osasuna",
      "homeScore": 4,
      "awayScore": 0,
      "matchId": 4205430,
      "matchDate": "2023-10-07T14:15:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2601322929,
      "eventType": "Miss",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 92.1,
      "y": 40.46952381,
      "min": 58,
      "isBlocked": false,
      "isOnTarget": false,
      "goalCrossedY": 40.637619048,
      "goalCrossedZ": 0.3595789456,
      "expectedGoals": 0.0582953542470932,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "SecondHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": -2.22044604925e-16,
        "y": 0.0541728808176097,
        "zoomRatio": 0.569481311395682
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8633,
      "awayTeamId": 8371,
      "homeTeamName": "Real Madrid",
      "awayTeamName": "Osasuna",
      "homeScore": 4,
      "awayScore": 0,
      "matchId": 4205430,
      "matchDate": "2023-10-07T14:15:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2601337239,
      "eventType": "Goal",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 102.8189655174,
      "y": 38.704523811,
      "min": 65,
      "isBlocked": false,
      "isOnTarget": true,
      "goalCrossedY": 36.5925,
      "goalCrossedZ": 0.160526315,
      "expectedGoals": 0.906255662441254,
      "expectedGoalsOnTarget": 0.9834,
      "shotType": "RightFoot",
      "situation": "FastBreak",
      "period": "SecondHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0.314153439153439,
        "y": 0.0424672791005291,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8633,
      "awayTeamId": 8371,
      "homeTeamName": "Real Madrid",
      "awayTeamName": "Osasuna",
      "homeScore": 4,
      "awayScore": 0,
      "matchId": 4205430,
      "matchDate": "2023-10-07T14:15:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2606246069,
      "eventType": "AttemptSaved",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 101.5862068968,
      "y": 43.1021875,
      "min": 15,
      "isBlocked": true,
      "isOnTarget": true,
      "blockedX": 102.4396551726,
      "blockedY": 41.7146875,
      "goalCrossedY": 36.745,
      "goalCrossedZ": 1.219999994,
      "expectedGoals": 0.079350158572197,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "FirstHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0.273809523809523,
        "y": 0.322751321164021,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8302,
      "awayTeamId": 8633,
      "homeTeamName": "Sevilla",
      "awayTeamName": "Real Madrid",
      "homeScore": 1,
      "awayScore": 1,
      "matchId": 4205440,
      "matchDate": "2023-10-21T16:30:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2606272535,
      "eventType": "AttemptSaved",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 92.8,
      "y": 38.536428573,
      "min": 40,
      "isBlocked": false,
      "isOnTarget": true,
      "blockedX": 99.5000000004,
      "blockedY": 36.8975,
      "goalCrossedY": 34.38125,
      "goalCrossedZ": 0.8539999958,
      "expectedGoals": 0.244718164205551,
      "expectedGoalsOnTarget": 0.0869,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "FirstHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0.899140211640211,
        "y": 0.225925924814815,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8302,
      "awayTeamId": 8633,
      "homeTeamName": "Sevilla",
      "awayTeamName": "Real Madrid",
      "homeScore": 1,
      "awayScore": 1,
      "matchId": 4205440,
      "matchDate": "2023-10-21T16:30:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2606306025,
      "eventType": "AttemptSaved",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 86.5676470584,
      "y": 45.6822929897,
      "min": 48,
      "isBlocked": true,
      "isOnTarget": true,
      "blockedX": 90.2,
      "blockedY": 43.3701910778,
      "goalCrossedY": 33.61875,
      "goalCrossedZ": 1.219999994,
      "expectedGoals": 0.0694756507873535,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "SecondHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 1.10085978835979,
        "y": 0.322751321164021,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": false,
      "box": "OutsideBox",
      "homeTeamId": 8302,
      "awayTeamId": 8633,
      "homeTeamName": "Sevilla",
      "awayTeamName": "Real Madrid",
      "homeScore": 1,
      "awayScore": 1,
      "matchId": 4205440,
      "matchDate": "2023-10-21T16:30:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2609552265,
      "eventType": "AttemptSaved",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 86.4602941172,
      "y": 34.1525,
      "min": 13,
      "isBlocked": true,
      "isOnTarget": true,
      "blockedX": 87.963235294,
      "blockedY": 34.1525,
      "goalCrossedY": 34.83875,
      "goalCrossedZ": 0.802631575,
      "expectedGoals": 0.0447121039032936,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "FirstHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0.778108465608464,
        "y": 0.212336395502646,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": false,
      "box": "OutsideBox",
      "homeTeamId": 8634,
      "awayTeamId": 8633,
      "homeTeamName": "Barcelona",
      "awayTeamName": "Real Madrid",
      "homeScore": 1,
      "awayScore": 2,
      "matchId": 4205445,
      "matchDate": "2023-10-28T14:15:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2609705977,
      "eventType": "AttemptSaved",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 87.5338235292,
      "y": 50.4466242021,
      "min": 68,
      "isBlocked": true,
      "isOnTarget": true,
      "blockedX": 89.1,
      "blockedY": 49.1154140104,
      "goalCrossedY": 34.99125,
      "goalCrossedZ": 0.6228421022,
      "expectedGoals": 0.00749506382271648,
      "shotType": "RightFoot",
      "situation": "FromCorner",
      "period": "SecondHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0.73776455026455,
        "y": 0.164773042910053,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": false,
      "box": "OutsideBox",
      "homeTeamId": 8634,
      "awayTeamId": 8633,
      "homeTeamName": "Barcelona",
      "awayTeamName": "Real Madrid",
      "homeScore": 1,
      "awayScore": 2,
      "matchId": 4205445,
      "matchDate": "2023-10-28T14:15:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2614186571,
      "eventType": "Miss",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 85.4941176464,
      "y": 54.7503317458,
      "min": 60,
      "isBlocked": false,
      "isOnTarget": false,
      "goalCrossedY": 28.959285713,
      "goalCrossedZ": 0.802631575,
      "expectedGoals": 0.0155140366405249,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "SecondHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 2,
        "y": 0.15922973001465,
        "zoomRatio": 0.749893722353719
      },
      "isSavedOffLine": false,
      "isFromInsideBox": false,
      "box": "OutsideBox",
      "homeTeamId": 8633,
      "awayTeamId": 8370,
      "homeTeamName": "Real Madrid",
      "awayTeamName": "Rayo Vallecano",
      "homeScore": 0,
      "awayScore": 0,
      "matchId": 4205461,
      "matchDate": "2023-11-05T20:00:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2614199867,
      "eventType": "Miss",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 97.6666666661,
      "y": 36.21125,
      "min": 88,
      "isBlocked": false,
      "isOnTarget": false,
      "goalCrossedY": 46.9434394871,
      "goalCrossedZ": 0.7127368386,
      "expectedGoals": 0.176208674907684,
      "shotType": "Header",
      "situation": "FromCorner",
      "period": "SecondHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0,
        "y": 0.0550654900739749,
        "zoomRatio": 0.292039840242411
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8633,
      "awayTeamId": 8370,
      "homeTeamName": "Real Madrid",
      "awayTeamName": "Rayo Vallecano",
      "homeScore": 0,
      "awayScore": 0,
      "matchId": 4205461,
      "matchDate": "2023-11-05T20:00:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2616654151,
      "eventType": "AttemptSaved",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 96.8947368413,
      "y": 38.368333335,
      "min": 16,
      "isBlocked": true,
      "isOnTarget": true,
      "blockedX": 98.7280701752,
      "blockedY": 37.696,
      "goalCrossedY": 34.07625,
      "goalCrossedZ": 1.219999994,
      "expectedGoals": 0.252933770418167,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "FirstHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0.979828042328042,
        "y": 0.322751321164021,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8633,
      "awayTeamId": 10267,
      "homeTeamName": "Real Madrid",
      "awayTeamName": "Valencia",
      "homeScore": 5,
      "awayScore": 1,
      "matchId": 4205466,
      "matchDate": "2023-11-11T20:00:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2616654403,
      "eventType": "Miss",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 102.0603448278,
      "y": 21.7571974559,
      "min": 16,
      "isBlocked": false,
      "isOnTarget": false,
      "goalCrossedY": 29.547619046,
      "goalCrossedZ": 1.5153684136,
      "expectedGoals": 0.0485122464597225,
      "shotType": "RightFoot",
      "situation": "FromCorner",
      "period": "FirstHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 2,
        "y": 0.340350124855916,
        "zoomRatio": 0.84898395691053
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8633,
      "awayTeamId": 10267,
      "homeTeamName": "Real Madrid",
      "awayTeamName": "Valencia",
      "homeScore": 5,
      "awayScore": 1,
      "matchId": 4205466,
      "matchDate": "2023-11-11T20:00:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2616674235,
      "eventType": "Goal",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 97.6666666661,
      "y": 35.3725,
      "min": 42,
      "isBlocked": false,
      "isOnTarget": true,
      "goalCrossedY": 37.43125,
      "goalCrossedZ": 1.1365263102,
      "expectedGoals": 0.248124003410339,
      "expectedGoalsOnTarget": 0.9107,
      "shotType": "OtherBodyParts",
      "situation": "RegularPlay",
      "period": "FirstHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0.0922619047619033,
        "y": 0.300668336031746,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8633,
      "awayTeamId": 10267,
      "homeTeamName": "Real Madrid",
      "awayTeamName": "Valencia",
      "homeScore": 5,
      "awayScore": 1,
      "matchId": 4205466,
      "matchDate": "2023-11-11T20:00:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2616690847,
      "eventType": "Goal",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 86.352941176,
      "y": 45.9625477669,
      "min": 49,
      "isBlocked": false,
      "isOnTarget": true,
      "goalCrossedY": 36.82125,
      "goalCrossedZ": 0.160526315,
      "expectedGoals": 0.035087876021862,
      "expectedGoalsOnTarget": 0.2182,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "SecondHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0.253637566137564,
        "y": 0.0424672791005291,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": false,
      "box": "OutsideBox",
      "homeTeamId": 8633,
      "awayTeamId": 10267,
      "homeTeamName": "Real Madrid",
      "awayTeamName": "Valencia",
      "homeScore": 5,
      "awayScore": 1,
      "matchId": 4205466,
      "matchDate": "2023-11-11T20:00:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2616702733,
      "eventType": "AttemptSaved",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 87.1044117644,
      "y": 34.38125,
      "min": 73,
      "isBlocked": false,
      "isOnTarget": true,
      "blockedX": 102.7241379312,
      "blockedY": 33.31375,
      "goalCrossedY": 35.44875,
      "goalCrossedZ": 0.2054736832,
      "expectedGoals": 0.0880435109138489,
      "expectedGoalsOnTarget": 0.1044,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "SecondHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0.616732804232803,
        "y": 0.0543581172486773,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": false,
      "box": "OutsideBox",
      "homeTeamId": 8633,
      "awayTeamId": 10267,
      "homeTeamName": "Real Madrid",
      "awayTeamName": "Valencia",
      "homeScore": 5,
      "awayScore": 1,
      "matchId": 4205466,
      "matchDate": "2023-11-11T20:00:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2633962047,
      "eventType": "AttemptSaved",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 95.2543859636,
      "y": 44.9816560467,
      "min": 20,
      "isBlocked": false,
      "isOnTarget": true,
      "blockedX": 102.7241379312,
      "blockedY": 37.43125,
      "goalCrossedY": 31.78875,
      "goalCrossedZ": 0.4045263138,
      "expectedGoals": 0.135722056031227,
      "expectedGoalsOnTarget": 0.5844,
      "shotType": "LeftFoot",
      "situation": "RegularPlay",
      "period": "FirstHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 1.58498677248677,
        "y": 0.107017543333333,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8633,
      "awayTeamId": 8661,
      "homeTeamName": "Real Madrid",
      "awayTeamName": "Mallorca",
      "homeScore": 1,
      "awayScore": 0,
      "matchId": 4205531,
      "matchDate": "2024-01-03T18:15:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2633965279,
      "eventType": "Miss",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 93.4,
      "y": 31.17875,
      "min": 30,
      "isBlocked": false,
      "isOnTarget": false,
      "goalCrossedY": 42.350625,
      "goalCrossedZ": 0.1797894728,
      "expectedGoals": 0.095988966524601,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "FirstHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0,
        "y": 0.0215300618576454,
        "zoomRatio": 0.452660728987352
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8633,
      "awayTeamId": 8661,
      "homeTeamName": "Real Madrid",
      "awayTeamName": "Mallorca",
      "homeScore": 1,
      "awayScore": 0,
      "matchId": 4205531,
      "matchDate": "2024-01-03T18:15:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2633967295,
      "eventType": "AttemptSaved",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 81.3587378648,
      "y": 33.77125,
      "min": 37,
      "isBlocked": false,
      "isOnTarget": true,
      "blockedX": 103.6724137932,
      "blockedY": 33.8475,
      "goalCrossedY": 32.0175,
      "goalCrossedZ": 1.6245263078,
      "expectedGoals": 0.0611943081021309,
      "expectedGoalsOnTarget": 0.1782,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "FirstHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 1.5244708994709,
        "y": 0.429768864497354,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": false,
      "box": "OutsideBox",
      "homeTeamId": 8633,
      "awayTeamId": 8661,
      "homeTeamName": "Real Madrid",
      "awayTeamName": "Mallorca",
      "homeScore": 1,
      "awayScore": 0,
      "matchId": 4205531,
      "matchDate": "2024-01-03T18:15:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2637956149,
      "eventType": "Goal",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 97.4736842099,
      "y": 36.44,
      "min": 67,
      "isBlocked": false,
      "isOnTarget": true,
      "goalCrossedY": 31.48375,
      "goalCrossedZ": 1.4639999928,
      "expectedGoals": 0.089894562959671,
      "expectedGoalsOnTarget": 0.864,
      "shotType": "OtherBodyParts",
      "situation": "RegularPlay",
      "period": "SecondHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 1.6656746031746,
        "y": 0.387301585396825,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8633,
      "awayTeamId": 9865,
      "homeTeamName": "Real Madrid",
      "awayTeamName": "Almeria",
      "homeScore": 3,
      "awayScore": 2,
      "matchId": 4205546,
      "matchDate": "2024-01-21T15:15:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2637963465,
      "eventType": "AttemptSaved",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 98.0526315785,
      "y": 36.21125,
      "min": 81,
      "isBlocked": false,
      "isOnTarget": true,
      "blockedX": 101.4913793106,
      "blockedY": 35.3725,
      "goalCrossedY": 34.07625,
      "goalCrossedZ": 0.6485263126,
      "expectedGoals": 0.239663004875183,
      "expectedGoalsOnTarget": 0.3083,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "SecondHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0.979828042328042,
        "y": 0.171567807566138,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8633,
      "awayTeamId": 9865,
      "homeTeamName": "Real Madrid",
      "awayTeamName": "Almeria",
      "homeScore": 3,
      "awayScore": 2,
      "matchId": 4205546,
      "matchDate": "2024-01-21T15:15:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2639623657,
      "eventType": "AttemptSaved",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 99.3070175438,
      "y": 43.044375,
      "min": 36,
      "isBlocked": false,
      "isOnTarget": true,
      "blockedX": 102.7241379312,
      "blockedY": 38.704523811,
      "goalCrossedY": 33.77125,
      "goalCrossedZ": 1.0979999946,
      "expectedGoals": 0.34091928601265,
      "expectedGoalsOnTarget": 0.2772,
      "shotType": "LeftFoot",
      "situation": "RegularPlay",
      "period": "FirstHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 1.06051587301587,
        "y": 0.290476189047619,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8306,
      "awayTeamId": 8633,
      "homeTeamName": "Las Palmas",
      "awayTeamName": "Real Madrid",
      "homeScore": 1,
      "awayScore": 2,
      "matchId": 4205557,
      "matchDate": "2024-01-27T15:15:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2639627653,
      "eventType": "Miss",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 80.6830097096,
      "y": 35.44875,
      "min": 41,
      "isBlocked": false,
      "isOnTarget": false,
      "goalCrossedY": 39.208809525,
      "goalCrossedZ": 0.3595789456,
      "expectedGoals": 0.0287972390651703,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "FirstHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0,
        "y": 0.0690328459649328,
        "zoomRatio": 0.725693650700349
      },
      "isSavedOffLine": false,
      "isFromInsideBox": false,
      "box": "OutsideBox",
      "homeTeamId": 8306,
      "awayTeamId": 8633,
      "homeTeamName": "Las Palmas",
      "awayTeamName": "Real Madrid",
      "homeScore": 1,
      "awayScore": 2,
      "matchId": 4205557,
      "matchDate": "2024-01-27T15:15:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2639628179,
      "eventType": "Miss",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 88.0705882352,
      "y": 47.15363057,
      "min": 42,
      "isBlocked": false,
      "isOnTarget": false,
      "goalCrossedY": 27.698571428,
      "goalCrossedZ": 5.9142069072,
      "expectedGoals": 0.0359176471829414,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "FirstHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 1.72159027104185,
        "y": 0.677248677248677,
        "zoomRatio": 0.432856009295758
      },
      "isSavedOffLine": false,
      "isFromInsideBox": false,
      "box": "OutsideBox",
      "homeTeamId": 8306,
      "awayTeamId": 8633,
      "homeTeamName": "Las Palmas",
      "awayTeamName": "Real Madrid",
      "homeScore": 1,
      "awayScore": 2,
      "matchId": 4205557,
      "matchDate": "2024-01-27T15:15:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2639695469,
      "eventType": "AttemptSaved",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 96.9912280694,
      "y": 43.7205095493,
      "min": 62,
      "isBlocked": true,
      "isOnTarget": true,
      "blockedX": 98.1491228066,
      "blockedY": 42.6396875,
      "goalCrossedY": 35.3725,
      "goalCrossedZ": 1.219999994,
      "expectedGoals": 0.0636754631996155,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "SecondHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0.636904761904761,
        "y": 0.322751321164021,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8306,
      "awayTeamId": 8633,
      "homeTeamName": "Las Palmas",
      "awayTeamName": "Real Madrid",
      "homeScore": 1,
      "awayScore": 2,
      "matchId": 4205557,
      "matchDate": "2024-01-27T15:15:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2639698727,
      "eventType": "Miss",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 97.7631578942,
      "y": 42.1771875,
      "min": 64,
      "isBlocked": false,
      "isOnTarget": false,
      "goalCrossedY": 34.99125,
      "goalCrossedZ": 5.1842758704,
      "expectedGoals": 0.163317561149597,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "SecondHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0.870507903494156,
        "y": 0.677248677248677,
        "zoomRatio": 0.493800882514086
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8306,
      "awayTeamId": 8633,
      "homeTeamName": "Las Palmas",
      "awayTeamName": "Real Madrid",
      "homeScore": 1,
      "awayScore": 2,
      "matchId": 4205557,
      "matchDate": "2024-01-27T15:15:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2639701861,
      "eventType": "Goal",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 100.4482758624,
      "y": 45.6822929897,
      "min": 65,
      "isBlocked": false,
      "isOnTarget": true,
      "goalCrossedY": 32.78,
      "goalCrossedZ": 0.3659999982,
      "expectedGoals": 0.163378775119782,
      "expectedGoalsOnTarget": 0.4416,
      "shotType": "LeftFoot",
      "situation": "RegularPlay",
      "period": "SecondHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 1.32275132275132,
        "y": 0.0968253963492064,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8306,
      "awayTeamId": 8633,
      "homeTeamName": "Las Palmas",
      "awayTeamName": "Real Madrid",
      "homeScore": 1,
      "awayScore": 2,
      "matchId": 4205557,
      "matchDate": "2024-01-27T15:15:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2639726277,
      "eventType": "AttemptSaved",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 95.7368421041,
      "y": 39.208809525,
      "min": 83,
      "isBlocked": true,
      "isOnTarget": true,
      "blockedX": 98.2456140347,
      "blockedY": 37.732,
      "goalCrossedY": 33.085,
      "goalCrossedZ": 1.219999994,
      "expectedGoals": 0.0980708226561546,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "SecondHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 1.24206349206349,
        "y": 0.322751321164021,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8306,
      "awayTeamId": 8633,
      "homeTeamName": "Las Palmas",
      "awayTeamName": "Real Madrid",
      "homeScore": 1,
      "awayScore": 2,
      "matchId": 4205557,
      "matchDate": "2024-01-27T15:15:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2641427299,
      "eventType": "AttemptSaved",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 94.7719298231,
      "y": 45.4020382125,
      "min": 12,
      "isBlocked": false,
      "isOnTarget": true,
      "blockedX": 101.5862068968,
      "blockedY": 37.756,
      "goalCrossedY": 32.85625,
      "goalCrossedZ": 0.2054736832,
      "expectedGoals": 0.157657220959663,
      "expectedGoalsOnTarget": 0.2559,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "FirstHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 1.30257936507937,
        "y": 0.0543581172486773,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8305,
      "awayTeamId": 8633,
      "homeTeamName": "Getafe",
      "awayTeamName": "Real Madrid",
      "homeScore": 0,
      "awayScore": 2,
      "matchId": 4205539,
      "matchDate": "2024-02-01T20:00:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2641441563,
      "eventType": "AttemptSaved",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 96.8947368413,
      "y": 37.66,
      "min": 63,
      "isBlocked": false,
      "isOnTarget": true,
      "blockedX": 99.1140350876,
      "blockedY": 36.745,
      "goalCrossedY": 34.4575,
      "goalCrossedZ": 0.4879999976,
      "expectedGoals": 0.227282643318176,
      "expectedGoalsOnTarget": 0.6927,
      "shotType": "RightFoot",
      "situation": "FastBreak",
      "period": "SecondHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0.878968253968253,
        "y": 0.129100528465608,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8305,
      "awayTeamId": 8633,
      "homeTeamName": "Getafe",
      "awayTeamName": "Real Madrid",
      "homeScore": 0,
      "awayScore": 2,
      "matchId": 4205539,
      "matchDate": "2024-02-01T20:00:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2641443429,
      "eventType": "AttemptSaved",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 92,
      "y": 39.965238096,
      "min": 69,
      "isBlocked": false,
      "isOnTarget": true,
      "blockedX": 97.3771929818,
      "blockedY": 37.672,
      "goalCrossedY": 34.07625,
      "goalCrossedZ": 1.059473679,
      "expectedGoals": 0.449304193258286,
      "expectedGoalsOnTarget": 0.1765,
      "shotType": "RightFoot",
      "situation": "FastBreak",
      "period": "SecondHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0.979828042328042,
        "y": 0.280284042063492,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8305,
      "awayTeamId": 8633,
      "homeTeamName": "Getafe",
      "awayTeamName": "Real Madrid",
      "homeScore": 0,
      "awayScore": 2,
      "matchId": 4205539,
      "matchDate": "2024-02-01T20:00:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2644751401,
      "eventType": "Goal",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 80.7956310688,
      "y": 49.255541399,
      "min": 6,
      "isBlocked": false,
      "isOnTarget": true,
      "goalCrossedY": 31.02625,
      "goalCrossedZ": 1.059473679,
      "expectedGoals": 0.0163144879043102,
      "expectedGoalsOnTarget": 0.3487,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "FirstHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 1.78670634920635,
        "y": 0.280284042063492,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": false,
      "box": "OutsideBox",
      "homeTeamId": 8633,
      "awayTeamId": 7732,
      "homeTeamName": "Real Madrid",
      "awayTeamName": "Girona",
      "homeScore": 4,
      "awayScore": 0,
      "matchId": 4205581,
      "matchDate": "2024-02-10T17:30:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2644789187,
      "eventType": "AttemptSaved",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 95.5438596479,
      "y": 41.7146875,
      "min": 45,
      "minAdded": 1,
      "isBlocked": true,
      "isOnTarget": true,
      "blockedX": 96.605263157,
      "blockedY": 40.973809524,
      "goalCrossedY": 34.61,
      "goalCrossedZ": 1.219999994,
      "expectedGoals": 0.0632040873169899,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "FirstHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0.838624338624339,
        "y": 0.322751321164021,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8633,
      "awayTeamId": 7732,
      "homeTeamName": "Real Madrid",
      "awayTeamName": "Girona",
      "homeScore": 4,
      "awayScore": 0,
      "matchId": 4205581,
      "matchDate": "2024-02-10T17:30:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2644792111,
      "eventType": "Miss",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 93.1,
      "y": 44.9816560467,
      "min": 45,
      "minAdded": 4,
      "isBlocked": false,
      "isOnTarget": false,
      "goalCrossedY": 26.111875,
      "goalCrossedZ": 0.2696842092,
      "expectedGoals": 0.0710088014602661,
      "shotType": "LeftFoot",
      "situation": "RegularPlay",
      "period": "FirstHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 2,
        "y": 0.03418863281198,
        "zoomRatio": 0.479201331114809
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8633,
      "awayTeamId": 7732,
      "homeTeamName": "Real Madrid",
      "awayTeamName": "Girona",
      "homeScore": 4,
      "awayScore": 0,
      "matchId": 4205581,
      "matchDate": "2024-02-10T17:30:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2644814683,
      "eventType": "AttemptSaved",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 101.1120689658,
      "y": 46.452993627,
      "min": 54,
      "isBlocked": false,
      "isOnTarget": true,
      "blockedX": 104.4310344828,
      "blockedY": 36.8975,
      "goalCrossedY": 32.55125,
      "goalCrossedZ": 0.1219999994,
      "expectedGoals": 0.0351236686110496,
      "expectedGoalsOnTarget": 0.1802,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "SecondHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 1.3832671957672,
        "y": 0.0322751321164021,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8633,
      "awayTeamId": 7732,
      "homeTeamName": "Real Madrid",
      "awayTeamName": "Girona",
      "homeScore": 4,
      "awayScore": 0,
      "matchId": 4205581,
      "matchDate": "2024-02-10T17:30:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2648036725,
      "eventType": "AttemptSaved",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 93.8,
      "y": 44.4912101866,
      "min": 8,
      "isBlocked": true,
      "isOnTarget": true,
      "blockedX": 94.8684210512,
      "blockedY": 43.3001273835,
      "goalCrossedY": 31.48375,
      "goalCrossedZ": 1.219999994,
      "expectedGoals": 0.0424026697874069,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "FirstHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 1.6656746031746,
        "y": 0.322751321164021,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8370,
      "awayTeamId": 8633,
      "homeTeamName": "Rayo Vallecano",
      "awayTeamName": "Real Madrid",
      "homeScore": 1,
      "awayScore": 1,
      "matchId": 4205586,
      "matchDate": "2024-02-18T13:00:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2648039369,
      "eventType": "AttemptSaved",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 95.7368421041,
      "y": 25.07125,
      "min": 11,
      "isBlocked": true,
      "isOnTarget": true,
      "blockedX": 97.7631578942,
      "blockedY": 26.774047619,
      "goalCrossedY": 34.38125,
      "goalCrossedZ": 1.219999994,
      "expectedGoals": 0.13382513821125,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "FirstHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0.899140211640211,
        "y": 0.322751321164021,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8370,
      "awayTeamId": 8633,
      "homeTeamName": "Rayo Vallecano",
      "awayTeamName": "Real Madrid",
      "homeScore": 1,
      "awayScore": 1,
      "matchId": 4205586,
      "matchDate": "2024-02-18T13:00:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2651342331,
      "eventType": "Miss",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 91.3,
      "y": 51.9179617824,
      "min": 31,
      "isBlocked": false,
      "isOnTarget": false,
      "goalCrossedY": 27.110238095,
      "goalCrossedZ": 0.7127368386,
      "expectedGoals": 0.022827273234725,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "FirstHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 2,
        "y": 0.1034486892911,
        "zoomRatio": 0.548640149270877
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8633,
      "awayTeamId": 8302,
      "homeTeamName": "Real Madrid",
      "awayTeamName": "Sevilla",
      "homeScore": 1,
      "awayScore": 0,
      "matchId": 4205597,
      "matchDate": "2024-02-25T20:00:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2651361093,
      "eventType": "AttemptSaved",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 95.7368421041,
      "y": 22.3877707046,
      "min": 55,
      "isBlocked": false,
      "isOnTarget": true,
      "blockedX": 103.103448276,
      "blockedY": 31.1025,
      "goalCrossedY": 36.21125,
      "goalCrossedZ": 1.0145263108,
      "expectedGoals": 0.0758984386920929,
      "expectedGoalsOnTarget": 0.2499,
      "shotType": "LeftFoot",
      "situation": "RegularPlay",
      "period": "SecondHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0.415013227513228,
        "y": 0.268393203915344,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8633,
      "awayTeamId": 8302,
      "homeTeamName": "Real Madrid",
      "awayTeamName": "Sevilla",
      "homeScore": 1,
      "awayScore": 0,
      "matchId": 4205597,
      "matchDate": "2024-02-25T20:00:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2651361941,
      "eventType": "Miss",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 90.6,
      "y": 50.2364331192,
      "min": 57,
      "isBlocked": false,
      "isOnTarget": false,
      "goalCrossedY": 27.278333333,
      "goalCrossedZ": 2.0483157794,
      "expectedGoals": 0.0319201983511448,
      "shotType": "RightFoot",
      "situation": "FromCorner",
      "period": "SecondHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 2,
        "y": 0.304733317029272,
        "zoomRatio": 0.562360525635391
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8633,
      "awayTeamId": 8302,
      "homeTeamName": "Real Madrid",
      "awayTeamName": "Sevilla",
      "homeScore": 1,
      "awayScore": 0,
      "matchId": 4205597,
      "matchDate": "2024-02-25T20:00:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2651367145,
      "eventType": "AttemptSaved",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 79.5567961176,
      "y": 42.581875,
      "min": 69,
      "isBlocked": false,
      "isOnTarget": true,
      "blockedX": 103.2931034484,
      "blockedY": 34.99125,
      "goalCrossedY": 34.305,
      "goalCrossedZ": 0.2825263144,
      "expectedGoals": 0.0233305785804987,
      "expectedGoalsOnTarget": 0.0228,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "SecondHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0.919312169312169,
        "y": 0.0747424112169312,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": false,
      "box": "OutsideBox",
      "homeTeamId": 8633,
      "awayTeamId": 8302,
      "homeTeamName": "Real Madrid",
      "awayTeamName": "Sevilla",
      "homeScore": 1,
      "awayScore": 0,
      "matchId": 4205597,
      "matchDate": "2024-02-25T20:00:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2653808071,
      "eventType": "Goal",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 101.206896552,
      "y": 35.22,
      "min": 45,
      "minAdded": 5,
      "isBlocked": false,
      "isOnTarget": true,
      "goalCrossedY": 36.44,
      "goalCrossedZ": 0.0834736838,
      "expectedGoals": 0.856963038444519,
      "expectedGoalsOnTarget": 0.7791,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "FirstHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0.354497354497353,
        "y": 0.0220829851322751,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 10267,
      "awayTeamId": 8633,
      "homeTeamName": "Valencia",
      "awayTeamName": "Real Madrid",
      "homeScore": 2,
      "awayScore": 2,
      "matchId": 4205609,
      "matchDate": "2024-03-02T20:00:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2653825279,
      "eventType": "Miss",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 94.7719298231,
      "y": 45.2619108239,
      "min": 54,
      "isBlocked": false,
      "isOnTarget": false,
      "goalCrossedY": 38.200238097,
      "goalCrossedZ": 3.6201379344,
      "expectedGoals": 0.0404774472117424,
      "shotType": "LeftFoot",
      "situation": "RegularPlay",
      "period": "SecondHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0.214227262366949,
        "y": 0.677248677248677,
        "zoomRatio": 0.707155375399886
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 10267,
      "awayTeamId": 8633,
      "homeTeamName": "Valencia",
      "awayTeamName": "Real Madrid",
      "homeScore": 2,
      "awayScore": 2,
      "matchId": 4205609,
      "matchDate": "2024-03-02T20:00:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2653839055,
      "eventType": "Goal",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 103.2931034484,
      "y": 36.2875,
      "min": 76,
      "isBlocked": false,
      "isOnTarget": true,
      "goalCrossedY": 34.4575,
      "goalCrossedZ": 1.059473679,
      "expectedGoals": 0.846833825111389,
      "expectedGoalsOnTarget": 0.873,
      "shotType": "Header",
      "situation": "RegularPlay",
      "period": "SecondHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0.878968253968253,
        "y": 0.280284042063492,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 10267,
      "awayTeamId": 8633,
      "homeTeamName": "Valencia",
      "awayTeamName": "Real Madrid",
      "homeScore": 2,
      "awayScore": 2,
      "matchId": 4205609,
      "matchDate": "2024-03-02T20:00:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2657823933,
      "eventType": "AttemptSaved",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 103.103448276,
      "y": 35.6775,
      "min": 21,
      "isBlocked": false,
      "isOnTarget": true,
      "blockedX": 104.4310344828,
      "blockedY": 34.83875,
      "goalCrossedY": 35.14375,
      "goalCrossedZ": 0.9374736796,
      "expectedGoals": 0.710533201694489,
      "expectedGoalsOnTarget": 0.9274,
      "shotType": "RightFoot",
      "situation": "FromCorner",
      "period": "FirstHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0.697420634920634,
        "y": 0.24800890994709,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8633,
      "awayTeamId": 9910,
      "homeTeamName": "Real Madrid",
      "awayTeamName": "Celta Vigo",
      "homeScore": 4,
      "awayScore": 0,
      "matchId": 4205621,
      "matchDate": "2024-03-10T17:30:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2657823957,
      "eventType": "Goal",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 102.2500000002,
      "y": 35.0675,
      "min": 21,
      "isBlocked": false,
      "isOnTarget": true,
      "goalCrossedY": 34.53375,
      "goalCrossedZ": 0.9374736796,
      "expectedGoals": 0.415024876594543,
      "expectedGoalsOnTarget": 0.7759,
      "shotType": "RightFoot",
      "situation": "FromCorner",
      "period": "FirstHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0.858796296296295,
        "y": 0.24800890994709,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8633,
      "awayTeamId": 9910,
      "homeTeamName": "Real Madrid",
      "awayTeamName": "Celta Vigo",
      "homeScore": 4,
      "awayScore": 0,
      "matchId": 4205621,
      "matchDate": "2024-03-10T17:30:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2657874525,
      "eventType": "AttemptSaved",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 90.7,
      "y": 43.3701910778,
      "min": 68,
      "isBlocked": false,
      "isOnTarget": true,
      "blockedX": 103.2931034484,
      "blockedY": 35.6775,
      "goalCrossedY": 33.61875,
      "goalCrossedZ": 0.2054736832,
      "expectedGoals": 0.0807032510638237,
      "expectedGoalsOnTarget": 0.0398,
      "shotType": "RightFoot",
      "situation": "FastBreak",
      "period": "SecondHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 1.10085978835979,
        "y": 0.0543581172486773,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8633,
      "awayTeamId": 9910,
      "homeTeamName": "Real Madrid",
      "awayTeamName": "Celta Vigo",
      "homeScore": 4,
      "awayScore": 0,
      "matchId": 4205621,
      "matchDate": "2024-03-10T17:30:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2660044485,
      "eventType": "Goal",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 93.5,
      "y": 28.454999999,
      "min": 4,
      "isBlocked": false,
      "isOnTarget": true,
      "goalCrossedY": 36.21125,
      "goalCrossedZ": 0.160526315,
      "expectedGoals": 0.521839201450348,
      "expectedGoalsOnTarget": 0.8076,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "FirstHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0.415013227513228,
        "y": 0.0424672791005291,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8371,
      "awayTeamId": 8633,
      "homeTeamName": "Osasuna",
      "awayTeamName": "Real Madrid",
      "homeScore": 2,
      "awayScore": 4,
      "matchId": 4205625,
      "matchDate": "2024-03-16T15:15:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2660055499,
      "eventType": "AttemptSaved",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 92.5,
      "y": 30.316,
      "min": 8,
      "isBlocked": false,
      "isOnTarget": true,
      "blockedX": 95.3508771917,
      "blockedY": 30.95,
      "goalCrossedY": 33.77125,
      "goalCrossedZ": 0.2825263144,
      "expectedGoals": 0.458564311265945,
      "expectedGoalsOnTarget": 0.2915,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "FirstHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 1.06051587301587,
        "y": 0.0747424112169312,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8371,
      "awayTeamId": 8633,
      "homeTeamName": "Osasuna",
      "awayTeamName": "Real Madrid",
      "homeScore": 2,
      "awayScore": 4,
      "matchId": 4205625,
      "matchDate": "2024-03-16T15:15:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2660119277,
      "eventType": "Miss",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 84.5121359224,
      "y": 46.6631847099,
      "min": 34,
      "isBlocked": false,
      "isOnTarget": false,
      "goalCrossedY": 27.950714285,
      "goalCrossedZ": 0.4430526294,
      "expectedGoals": 0.0253636427223682,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "FirstHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 2,
        "y": 0.073240486608426,
        "zoomRatio": 0.624867162519204
      },
      "isSavedOffLine": false,
      "isFromInsideBox": false,
      "box": "OutsideBox",
      "homeTeamId": 8371,
      "awayTeamId": 8633,
      "homeTeamName": "Osasuna",
      "awayTeamName": "Real Madrid",
      "homeScore": 2,
      "awayScore": 4,
      "matchId": 4205625,
      "matchDate": "2024-03-16T15:15:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2660203879,
      "eventType": "Goal",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 100.6379310348,
      "y": 43.8606369379,
      "min": 64,
      "isBlocked": false,
      "isOnTarget": true,
      "goalCrossedY": 33.695,
      "goalCrossedZ": 0.2054736832,
      "expectedGoals": 0.211648732423782,
      "expectedGoalsOnTarget": 0.1883,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "SecondHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 1.08068783068783,
        "y": 0.0543581172486773,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8371,
      "awayTeamId": 8633,
      "homeTeamName": "Osasuna",
      "awayTeamName": "Real Madrid",
      "homeScore": 2,
      "awayScore": 4,
      "matchId": 4205625,
      "matchDate": "2024-03-16T15:15:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2660210799,
      "eventType": "Miss",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 97.2807017537,
      "y": 44.6313375752,
      "min": 68,
      "isBlocked": false,
      "isOnTarget": false,
      "goalCrossedY": 25.99625,
      "goalCrossedZ": 0.3595789456,
      "expectedGoals": 0.141570582985878,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "SecondHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 2,
        "y": 0.0449263089926597,
        "zoomRatio": 0.472278619397158
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8371,
      "awayTeamId": 8633,
      "homeTeamName": "Osasuna",
      "awayTeamName": "Real Madrid",
      "homeScore": 2,
      "awayScore": 4,
      "matchId": 4205625,
      "matchDate": "2024-03-16T15:15:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2672085593,
      "eventType": "AttemptSaved",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 91.1,
      "y": 43.4402547721,
      "min": 67,
      "isBlocked": false,
      "isOnTarget": true,
      "blockedX": 103.4827586208,
      "blockedY": 35.22,
      "goalCrossedY": 34.61,
      "goalCrossedZ": 0.2825263144,
      "expectedGoals": 0.0925910025835037,
      "expectedGoalsOnTarget": 0.0333,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "SecondHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0.838624338624339,
        "y": 0.0747424112169312,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8661,
      "awayTeamId": 8633,
      "homeTeamName": "Mallorca",
      "awayTeamName": "Real Madrid",
      "homeScore": 0,
      "awayScore": 1,
      "matchId": 4205646,
      "matchDate": "2024-04-13T16:30:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2672087035,
      "eventType": "AttemptSaved",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 86.1382352936,
      "y": 31.4075,
      "min": 69,
      "isBlocked": true,
      "isOnTarget": true,
      "blockedX": 88.2852941176,
      "blockedY": 31.56,
      "goalCrossedY": 32.78,
      "goalCrossedZ": 1.219999994,
      "expectedGoals": 0.0624486766755581,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "SecondHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 1.32275132275132,
        "y": 0.322751321164021,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": false,
      "box": "OutsideBox",
      "homeTeamId": 8661,
      "awayTeamId": 8633,
      "homeTeamName": "Mallorca",
      "awayTeamName": "Real Madrid",
      "homeScore": 0,
      "awayScore": 1,
      "matchId": 4205646,
      "matchDate": "2024-04-13T16:30:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2672089961,
      "eventType": "AttemptSaved",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 87.3191176468,
      "y": 47.9943949016,
      "min": 73,
      "isBlocked": false,
      "isOnTarget": true,
      "blockedX": 102.7241379312,
      "blockedY": 36.51625,
      "goalCrossedY": 32.9325,
      "goalCrossedZ": 1.3034736778,
      "expectedGoals": 0.02861980907619,
      "expectedGoalsOnTarget": 0.0682,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "SecondHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 1.28240740740741,
        "y": 0.344834306296296,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": false,
      "box": "OutsideBox",
      "homeTeamId": 8661,
      "awayTeamId": 8633,
      "homeTeamName": "Mallorca",
      "awayTeamName": "Real Madrid",
      "homeScore": 0,
      "awayScore": 1,
      "matchId": 4205646,
      "matchDate": "2024-04-13T16:30:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2672109447,
      "eventType": "AttemptSaved",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 95.5438596479,
      "y": 41.656875,
      "min": 90,
      "minAdded": 4,
      "isBlocked": false,
      "isOnTarget": true,
      "blockedX": 101.3965517244,
      "blockedY": 37.58375,
      "goalCrossedY": 35.75375,
      "goalCrossedZ": 0.4045263138,
      "expectedGoals": 0.154251933097839,
      "expectedGoalsOnTarget": 0.0946,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "SecondHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0.536044973544974,
        "y": 0.107017543333333,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8661,
      "awayTeamId": 8633,
      "homeTeamName": "Mallorca",
      "awayTeamName": "Real Madrid",
      "homeScore": 0,
      "awayScore": 1,
      "matchId": 4205646,
      "matchDate": "2024-04-13T16:30:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2676619369,
      "eventType": "AttemptSaved",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 85.4941176464,
      "y": 42.92875,
      "min": 4,
      "isBlocked": true,
      "isOnTarget": true,
      "blockedX": 87.3191176468,
      "blockedY": 42.4084375,
      "goalCrossedY": 35.83,
      "goalCrossedZ": 1.219999994,
      "expectedGoals": 0.0245685502886772,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "FirstHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0.515873015873016,
        "y": 0.322751321164021,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": false,
      "box": "OutsideBox",
      "homeTeamId": 8633,
      "awayTeamId": 8634,
      "homeTeamName": "Real Madrid",
      "awayTeamName": "Barcelona",
      "homeScore": 3,
      "awayScore": 2,
      "matchId": 4205658,
      "matchDate": "2024-04-21T19:00:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2676623091,
      "eventType": "Miss",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 95.5438596479,
      "y": 32.17,
      "min": 8,
      "isBlocked": false,
      "isOnTarget": false,
      "goalCrossedY": 37.27875,
      "goalCrossedZ": 4.0980689704,
      "expectedGoals": 0.245471283793449,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "FirstHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0.458152335510263,
        "y": 0.677248677248677,
        "zoomRatio": 0.624684459556601
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8633,
      "awayTeamId": 8634,
      "homeTeamName": "Real Madrid",
      "awayTeamName": "Barcelona",
      "homeScore": 3,
      "awayScore": 2,
      "matchId": 4205658,
      "matchDate": "2024-04-21T19:00:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2676626991,
      "eventType": "Miss",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 100.732758621,
      "y": 36.8975,
      "min": 13,
      "isBlocked": false,
      "isOnTarget": false,
      "goalCrossedY": 40.637619048,
      "goalCrossedZ": 3.0118620704,
      "expectedGoals": 0.383250504732132,
      "shotType": "Header",
      "situation": "SetPiece",
      "period": "FirstHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": -2.22044604925e-16,
        "y": 0.453756391956166,
        "zoomRatio": 0.569481311395682
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8633,
      "awayTeamId": 8634,
      "homeTeamName": "Real Madrid",
      "awayTeamName": "Barcelona",
      "homeScore": 3,
      "awayScore": 2,
      "matchId": 4205658,
      "matchDate": "2024-04-21T19:00:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2676630661,
      "eventType": "Goal",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 94,
      "y": 34,
      "min": 18,
      "isBlocked": false,
      "isOnTarget": true,
      "goalCrossedY": 32.39875,
      "goalCrossedZ": 0.4879999976,
      "expectedGoals": 0.7884,
      "expectedGoalsOnTarget": 0.9644,
      "shotType": "RightFoot",
      "situation": "Penalty",
      "period": "FirstHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 1.42361111111111,
        "y": 0.129100528465608,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8633,
      "awayTeamId": 8634,
      "homeTeamName": "Real Madrid",
      "awayTeamName": "Barcelona",
      "homeScore": 3,
      "awayScore": 2,
      "matchId": 4205658,
      "matchDate": "2024-04-21T19:00:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2676665411,
      "eventType": "Miss",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 95.640350876,
      "y": 22.3877707046,
      "min": 55,
      "isBlocked": false,
      "isOnTarget": false,
      "goalCrossedY": 28.707142856,
      "goalCrossedZ": 3.1335172432,
      "expectedGoals": 0.124959632754326,
      "shotType": "RightFoot",
      "situation": "FastBreak",
      "period": "SecondHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 2,
        "y": 0.592027549194704,
        "zoomRatio": 0.714170040331624
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8633,
      "awayTeamId": 8634,
      "homeTeamName": "Real Madrid",
      "awayTeamName": "Barcelona",
      "homeScore": 3,
      "awayScore": 2,
      "matchId": 4205658,
      "matchDate": "2024-04-21T19:00:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2676680993,
      "eventType": "AttemptSaved",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 100.4482758624,
      "y": 42.6975,
      "min": 78,
      "isBlocked": false,
      "isOnTarget": true,
      "blockedX": 103.6724137932,
      "blockedY": 37.94809524,
      "goalCrossedY": 36.21125,
      "goalCrossedZ": 0.6934736808,
      "expectedGoals": 0.298362553119659,
      "expectedGoalsOnTarget": 0.1068,
      "shotType": "LeftFoot",
      "situation": "FastBreak",
      "period": "SecondHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0.415013227513228,
        "y": 0.183458645714286,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8633,
      "awayTeamId": 8634,
      "homeTeamName": "Real Madrid",
      "awayTeamName": "Barcelona",
      "homeScore": 3,
      "awayScore": 2,
      "matchId": 4205658,
      "matchDate": "2024-04-21T19:00:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2682403889,
      "eventType": "AttemptSaved",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 91,
      "y": 34.53375,
      "min": 90,
      "minAdded": 3,
      "isBlocked": false,
      "isOnTarget": true,
      "blockedX": 103.2931034484,
      "blockedY": 34,
      "goalCrossedY": 34.7625,
      "goalCrossedZ": 0.3274736826,
      "expectedGoals": 0.140986621379852,
      "expectedGoalsOnTarget": 0.0507,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "SecondHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0.798280423280423,
        "y": 0.0866332493650794,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8633,
      "awayTeamId": 8385,
      "homeTeamName": "Real Madrid",
      "awayTeamName": "Cadiz",
      "homeScore": 3,
      "awayScore": 0,
      "matchId": 4205679,
      "matchDate": "2024-05-04T14:15:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2687440213,
      "eventType": "Miss",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 92,
      "y": 49.8861146477,
      "min": 20,
      "isBlocked": false,
      "isOnTarget": false,
      "goalCrossedY": 38.452380954,
      "goalCrossedZ": 0.5329473658,
      "expectedGoals": 0.0322474353015423,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "FirstHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0,
        "y": 0.11969940831797,
        "zoomRatio": 0.84898395691053
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8633,
      "awayTeamId": 9866,
      "homeTeamName": "Real Madrid",
      "awayTeamName": "Deportivo Alaves",
      "homeScore": 5,
      "awayScore": 0,
      "matchId": 4205702,
      "matchDate": "2024-05-14T19:30:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2687443347,
      "eventType": "Goal",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 99.2105263157,
      "y": 32.6275,
      "min": 27,
      "isBlocked": false,
      "isOnTarget": true,
      "goalCrossedY": 33.61875,
      "goalCrossedZ": 0.2439999988,
      "expectedGoals": 0.366736024618149,
      "expectedGoalsOnTarget": 0.6903,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "FirstHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 1.10085978835979,
        "y": 0.0645502642328042,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8633,
      "awayTeamId": 9866,
      "homeTeamName": "Real Madrid",
      "awayTeamName": "Deportivo Alaves",
      "homeScore": 5,
      "awayScore": 0,
      "matchId": 4205702,
      "matchDate": "2024-05-14T19:30:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2687449933,
      "eventType": "Miss",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 86.2455882348,
      "y": 21.8272611502,
      "min": 41,
      "isBlocked": false,
      "isOnTarget": false,
      "goalCrossedY": 38.452380954,
      "goalCrossedZ": 3.6201379344,
      "expectedGoals": 0.0430905744433403,
      "shotType": "LeftFoot",
      "situation": "FastBreak",
      "period": "FirstHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0.167056845251542,
        "y": 0.677248677248677,
        "zoomRatio": 0.707155375399886
      },
      "isSavedOffLine": false,
      "isFromInsideBox": false,
      "box": "OutsideBox",
      "homeTeamId": 8633,
      "awayTeamId": 9866,
      "homeTeamName": "Real Madrid",
      "awayTeamName": "Deportivo Alaves",
      "homeScore": 5,
      "awayScore": 0,
      "matchId": 4205702,
      "matchDate": "2024-05-14T19:30:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2687452829,
      "eventType": "AttemptSaved",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 92.5,
      "y": 28.286904761,
      "min": 45,
      "minAdded": 3,
      "isBlocked": true,
      "isOnTarget": true,
      "blockedX": 94.5789473669,
      "blockedY": 29.799761903,
      "goalCrossedY": 36.05875,
      "goalCrossedZ": 1.219999994,
      "expectedGoals": 0.129451557993889,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "FirstHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0.455357142857142,
        "y": 0.322751321164021,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8633,
      "awayTeamId": 9866,
      "homeTeamName": "Real Madrid",
      "awayTeamName": "Deportivo Alaves",
      "homeScore": 5,
      "awayScore": 0,
      "matchId": 4205702,
      "matchDate": "2024-05-14T19:30:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2687459941,
      "eventType": "AttemptSaved",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 95.5438596479,
      "y": 44.4912101866,
      "min": 56,
      "isBlocked": false,
      "isOnTarget": true,
      "blockedX": 104.1465517242,
      "blockedY": 36.5925,
      "goalCrossedY": 36.745,
      "goalCrossedZ": 0.2825263144,
      "expectedGoals": 0.0481313616037369,
      "expectedGoalsOnTarget": 0.1837,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "SecondHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0.273809523809523,
        "y": 0.0747424112169312,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8633,
      "awayTeamId": 9866,
      "homeTeamName": "Real Madrid",
      "awayTeamName": "Deportivo Alaves",
      "homeScore": 5,
      "awayScore": 0,
      "matchId": 4205702,
      "matchDate": "2024-05-14T19:30:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2687462445,
      "eventType": "Goal",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 98.3421052628,
      "y": 20.84636943,
      "min": 70,
      "isBlocked": false,
      "isOnTarget": true,
      "goalCrossedY": 36.2875,
      "goalCrossedZ": 1.380526309,
      "expectedGoals": 0.086082860827446,
      "expectedGoalsOnTarget": 0.4364,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "SecondHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 0.39484126984127,
        "y": 0.36521860026455,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8633,
      "awayTeamId": 9866,
      "homeTeamName": "Real Madrid",
      "awayTeamName": "Deportivo Alaves",
      "homeScore": 5,
      "awayScore": 0,
      "matchId": 4205702,
      "matchDate": "2024-05-14T19:30:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2691847127,
      "eventType": "AttemptSaved",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 102.2500000002,
      "y": 30.232,
      "min": 33,
      "isBlocked": false,
      "isOnTarget": true,
      "blockedX": 103.9568965518,
      "blockedY": 30.41625,
      "goalCrossedY": 33.61875,
      "goalCrossedZ": 0.160526315,
      "expectedGoals": 0.235288843512535,
      "expectedGoalsOnTarget": 0.6599,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "FirstHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 1.10085978835979,
        "y": 0.0424672791005291,
        "zoomRatio": 1
      },
      "isSavedOffLine": false,
      "isFromInsideBox": true,
      "box": "InsideBox",
      "homeTeamId": 8633,
      "awayTeamId": 8603,
      "homeTeamName": "Real Madrid",
      "awayTeamName": "Real Betis",
      "homeScore": 0,
      "awayScore": 0,
      "matchId": 4205721,
      "matchDate": "2024-05-25T19:00:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    },
    {
      "id": 2691892243,
      "eventType": "Miss",
      "teamId": 8633,
      "playerId": 846033,
      "playerName": "Vinicius Junior",
      "x": 86.1382352936,
      "y": 36.2875,
      "min": 75,
      "isBlocked": false,
      "isOnTarget": false,
      "goalCrossedY": 22.5979617875,
      "goalCrossedZ": 3.6201379344,
      "expectedGoals": 0.0569401569664478,
      "shotType": "RightFoot",
      "situation": "RegularPlay",
      "period": "SecondHalf",
      "isOwnGoal": false,
      "onGoalShot": {
        "x": 2,
        "y": 0.317499193296095,
        "zoomRatio": 0.331519674776743
      },
      "isSavedOffLine": false,
      "isFromInsideBox": false,
      "box": "OutsideBox",
      "homeTeamId": 8633,
      "awayTeamId": 8603,
      "homeTeamName": "Real Madrid",
      "awayTeamName": "Real Betis",
      "homeScore": 0,
      "awayScore": 0,
      "matchId": 4205721,
      "matchDate": "2024-05-25T19:00:00Z",
      "teamColor": "#085098",
      "teamColorDark": "#ffffff"
    }
  ],
  "keeperShotmap": null
}

'''

# %%
import json
import pandas as pd

# Assuming json_data and shotmap are already defined and contain the relevant data

# Parse the JSON data
data = json.loads(json_data)
shotmap = data['shotmap']

player_name = shotmap[0]["playerName"]

print("Player Name: ", player_name)

# Extract the 'statValue' for the "Minutes" item and calculate the number of 90s played
minutes_value = None
nintysplayed = None
for item in data['topStatCard']['items']:
    if item['title'] == "Minutes":
        minutes_value = float(item['statValue'])
        nintysplayed = minutes_value / 90.0
        nintysplayed = round(nintysplayed, 3)  # Format to 3 decimal places
        break

print("90s Played:", nintysplayed)

# Initializing the stats
total_shots = 0
total_goals = 0
open_play_goals = 0
shots_on_target = 0
open_play_sot = 0
total_expected_goals = 0.0
total_expected_goals_on_target = 0.0
xGop = 0.0
xGOTop = 0.0

for shot in shotmap:
    total_shots += 1
    if shot['eventType'] == 'Goal':
        total_goals += 1
    if shot['eventType'] == 'Goal' and (shot['situation'] == "RegularPlay" or shot['situation'] == "FastBreak"):
        open_play_goals += 1
    if shot['isOnTarget'] and not shot['isBlocked']:
        shots_on_target += 1
    if shot['isOnTarget'] and not shot['isBlocked'] and (shot['situation'] == "RegularPlay" or shot['situation'] == "FastBreak"):
        open_play_sot += 1
    total_expected_goals += shot['expectedGoals']
    if 'expectedGoalsOnTarget' in shot:
        total_expected_goals_on_target += shot['expectedGoalsOnTarget']
    if shot['situation'] == "RegularPlay" or shot['situation'] == "FastBreak":
        xGop += shot['expectedGoals']
    if 'expectedGoalsOnTarget' in shot and (shot['situation'] == "RegularPlay" or shot['situation'] == "FastBreak"):
        xGOTop += shot['expectedGoalsOnTarget']

print("Total Shots:", total_shots)
print("Total Goals:", total_goals)
print("Goals from Open Play", open_play_goals)
print(f"Total number of unblocked shots on target: {shots_on_target}")
print(f"Total number of unblocked shots on target from open play: {open_play_sot}")
print(f"Total Expected Goals (xG): {total_expected_goals:.3f}")
print(f"Total Expected Goals on Target (xGOT): {total_expected_goals_on_target:.3f}")
print(f"Expected Goals from Open Play (xGop): {xGop:.3f}")
print(f"Expected Goals on Target from Open Play (xGOTop): {xGOTop:.3f}")


# Create a DataFrame
stats_dict = {
    "Player Name": [player_name],
    "90's Played": [nintysplayed],
    "Total Shots": [total_shots],
    "Total Goals": [total_goals],
    "Open Play Goals": [open_play_goals],
    "Shots on Target": [shots_on_target],
    "SoTop": [open_play_sot],
    "xG": [round(total_expected_goals, 3)],
    "xGOT": [round(total_expected_goals_on_target, 3)],
    "xGop": [round(xGop, 3)],
    "xGOTop": [round(xGOTop, 3)]
}

df = pd.DataFrame(stats_dict)

df.head()
# Out:
# Player Name:  Vinicius Junior
# 90s Played: 20.8
# Total Shots: 78
# Total Goals: 15
# Goals from Open Play 13
# Total number of unblocked shots on target: 39
# Total number of unblocked shots on target from open play: 36
# Total Expected Goals (xG): 13.412
# Total Expected Goals on Target (xGOT): 15.736
# Expected Goals from Open Play (xGop): 10.850
# Expected Goals on Target from Open Play (xGOTop): 13.068
#        Player Name  90's Played  Total Shots  Total Goals  Open Play Goals  \
# 0  Vinicius Junior         20.8           78           15               13
#
#    Shots on Target  SoTop      xG    xGOT   xGop  xGOTop
# 0               39     36  13.412  15.736  10.85  13.068

# %%
# Check column names for whitespace
df.columns = df.columns.str.strip()

# Adding more columns
df['xGop/Sh'] = df['xGop'] / df['Total Shots']

df['conversion rate (%)'] = (df['Total Goals'] / df['Shots on Target'])*100

df['G-xG'] = df['Total Goals'] - df['xG']

df['op:G-xG'] = df['Open Play Goals'] - df['xGop']

df['xGOT_op_diff'] = df['xGOT'] - df['xGOTop']

df['Adj. SGA'] = df['xGOTop'] - df['xGop']

df['Shot Quality'] = df['xGOTop'] / df['SoTop']

# Print the DataFrame to verify the new column
df.head()
# Out:
#        Player Name  90's Played  Total Shots  Total Goals  Open Play Goals  \
# 0  Vinicius Junior         20.8           78           15               13
#
#    Shots on Target  SoTop      xG    xGOT   xGop  xGOTop   xGop/Sh  \
# 0               39     36  13.412  15.736  10.85  13.068  0.139103
#
#    conversion rate (%)   G-xG  op:G-xG  xGOT_op_diff  Adj. SGA  Shot Quality
# 0            38.461538  1.588     2.15         2.668     2.218         0.363

# %%
import numpy as np

shot_points = []

for shot in shotmap:
    if shot['situation'] == "RegularPlay" or shot['situation'] == "FastBreak":
        shot_points.append((shot['x'], shot['y']))
    

shot_points = np.array(shot_points)
shot_points
# Out:
# array([[ 95.15789474,  44.07082802],
#        [ 97.0877193 ,  44.3510828 ],
#        [ 94.77192982,  42.8709375 ],
#        [ 75.95291262,  37.43125   ],
#        [101.87068966,  44.98165605],
#        [ 91.1       ,  28.95928571],
#        [ 92.2       ,  46.38292993],
#        [ 92.5       ,  40.38547619],
#        [ 91.2       ,  42.2928125 ],
#        [ 92.1       ,  40.46952381],
#        [102.81896552,  38.70452381],
#        [101.5862069 ,  43.1021875 ],
#        [ 92.8       ,  38.53642857],
#        [ 86.56764706,  45.68229299],
#        [ 86.46029412,  34.1525    ],
#        [ 85.49411765,  54.75033175],
#        [ 96.89473684,  38.36833334],
#        [ 97.66666667,  35.3725    ],
#        [ 86.35294118,  45.96254777],
#        [ 87.10441176,  34.38125   ],
#        [ 95.25438596,  44.98165605],
#        [ 93.4       ,  31.17875   ],
#        [ 81.35873786,  33.77125   ],
#        [ 97.47368421,  36.44      ],
#        [ 98.05263158,  36.21125   ],
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches

shot_points = []

for shot in shotmap:
    if shot['situation'] == "RegularPlay" or shot['situation'] == "FastBreak":
        shot_points.append((shot['x'], shot['y']))
    

shot_points = np.array(shot_points)

# Function to create the pitch
def create_half_pitch(length=105, width=68):
    """
    Creates half a football pitch using matplotlib.
    """
    fig, ax = plt.subplots(figsize=(10, 7))

    # Pitch Outline & Centre Line
    plt.plot([105, 105], [0, width], color="black", linewidth=1.5)  # Left side (halfway line)
    plt.plot([105, 52.5], [width, width], color="black", linewidth=1.5)
    plt.plot([52.5, 52.5], [width, 0], color="black", linewidth=1.5)  # Right side (goal line)
    plt.plot([52.5, 105], [0, 0], color="black", linewidth=1.5)

    # Penalty Area (16 meters deep, 39 meters wide)
    plt.plot([105 - 16, 105 - 16], [14.5, 14.5 + 39], color="black", linewidth=1.5)
    plt.plot([105, 105 - 16], [14.5, 14.5], color="black", linewidth=1.5)
    plt.plot([105 - 16, 105], [14.5 + 39, 14.5 + 39], color="black", linewidth=1.5)

    # 6-yard Box (5.5 meters deep, 8 meters wide)
    plt.plot([105 - 5.5, 105 - 5.5], [34 - 4, 34 + 4], color="black", linewidth=1.5)  # 34 is the center line, 4 is half of 8 meters
    plt.plot([105, 105 - 5.5], [34 - 4, 34 - 4], color="black", linewidth=1.5)  # Top horizontal line
    plt.plot([105 - 5.5, 105], [34 + 4, 34 + 4], color="black", linewidth=1.5)  # Bottom horizontal line

    # Goal
    plt.plot([105 + 2, 105], [34 - 3.66, 34 - 3.66], color="black")
    plt.plot([105 + 2, 105], [34 + 3.66, 34 + 3.66], color="black")
    plt.plot([105 + 2, 105 + 2], [34 - 3.66, 34 + 3.66], color="black")

    # Add the goal
    goal = patches.Rectangle((105, 34 - 7.32 / 2), 2, 7.32, linewidth=1.5, edgecolor='black', facecolor='none')
    ax.add_patch(goal)

    # Add the penalty spot
    penalty_spot_x = 94
    penalty_spot_y = 34
    ax.plot(penalty_spot_x, penalty_spot_y, 'ko', markersize=8)  # 'ko' means black color, 'o' shape

    # Add the penalty arc
    arc = patches.Arc((penalty_spot_x+0.2, penalty_spot_y), 18, 18, angle=0, theta1=125, theta2=235, color='black', linewidth=1.5)
    ax.add_patch(arc)

    # Tidy Axes
    plt.axis('off')

    return fig, ax

# Create the half pitch
fig, ax = create_half_pitch()

# Plot the shots using the numpy array
ax.plot(shot_points[:, 0], shot_points[:, 1], 'ro', markersize=10, alpha=0.75) 

# Set the limits to show only the half pitch
ax.set_xlim(52.5, 105)
ax.set_ylim(0, 68)

plt.show()

# %%
from scipy.spatial import ConvexHull
import matplotlib.colors as mcolors
import matplotlib.pyplot as plt

# Assuming shot_points and df are already defined earlier in your script

# Compute the convex hull
hull = ConvexHull(shot_points)

# Create the half pitch
fig, ax = create_half_pitch()

# Initialize the colormap and normalization
cmap = plt.get_cmap("coolwarm").reversed()
norm = mcolors.Normalize(vmin=0.2, vmax=0.5)

# Plot the convex hull
for simplex in hull.simplices:
    ax.plot(shot_points[simplex, 0], shot_points[simplex, 1], 'k-')

# Calculate the transparency based on the 'Shot Quality' from df
player_name = "Vinicius Junior"  # Example player name
shotq_value = df.loc[df['Player Name'] == player_name, 'Shot Quality'].values[0]

shotq_value = max(0.2, min(shotq_value, 0.5))
color = cmap(norm(shotq_value))

# Fill the convex hull with transparency
ax.fill(shot_points[hull.vertices, 0], shot_points[hull.vertices, 1], color=color, alpha=1)

# Set the title with the player name in bold
ax.set_title(f"Shot Locations from open play for {player_name}", fontsize=12)
ax.title.set_text(f"Shot Locations from open play for " + r"$\bf{" + player_name.replace(' ', r'\ ') + "}$")

# Set the limits to show only the half pitch
ax.set_xlim(52.5, 105)
ax.set_ylim(0, 68)

cbar_ax = fig.add_axes([0.93, 0.15, 0.02, 0.7])
fig.colorbar(plt.cm.ScalarMappable(norm=norm, cmap=cmap), cax=cbar_ax)

# Define the function to format player stats
def player_stat_disp(player_row):
    return (
        f"""
        90s Played: {player_row["90's Played"]:.2f}\n
        Total Goals: {player_row['Total Goals']}\n
        Open Play Goals: {player_row['Open Play Goals']}\n
        Total Shots: {player_row['Total Shots']}\n
        Shots on Target: {player_row['Shots on Target']}\n
        xG: {player_row['xG']:.2f}\n
        xG Open Play: {player_row['xGop']:.2f}\n
        xGOT: {player_row['xGOT']:.2f}\n
        xGOT Open Play: {player_row['xGOTop']:.2f}\n
        Conversion Rate: {player_row['conversion rate (%)']:.2f}\n
        Adj. SGA: {player_row['Adj. SGA']:.2f}\n
        Shot Quality: {player_row['Shot Quality']:.3f}\n
        """
    )

player_row = df[df['Player Name'] == player_name].iloc[0]
stat_text = player_stat_disp(player_row)

# Bold the numbers in the stats
bold_text = "\n".join([
    line.replace(f"{num}", r"$\bf{" + str(num) + "}$") if num else line
    for line in stat_text.split('\n')
    for num in [line.split(': ')[-1]] if num.replace('.', '', 1).isdigit()
])

# Add the "Shot Quality Meter" text vertically next to the color bar
fig.text(1.02, 0.5, 'Shot Quality Meter', va='center', rotation='vertical', fontsize=12, fontweight='bold')

# Add the stats text to the plot (bottom left corner) with left alignment and reduced spacing
ax.text(55, 5, bold_text, ha='left', va='bottom', fontsize=10, color='black', linespacing=1.25)

plt.show()
